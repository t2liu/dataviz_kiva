# %%
import pandas as pd
from collections import Counter

# %%
# data_path = '/Users/ting2liu/data/kiva/kiva_ds_csv/NEW/'
data_path = '../'

# %%
df = pd.read_csv(data_path + 'loans.csv')

# %%
df.columns

# %%
df = pd.read_csv(data_path + 'loans.csv', parse_dates=["POSTED_TIME", "PLANNED_EXPIRATION_TIME",
                               "DISBURSE_TIME", "RAISED_TIME"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3f30f41b878d> in <module>()
#       1 df = pd.read_csv(data_path + 'loans.csv', parse_dates=["POSTED_TIME", "PLANNED_EXPIRATION_TIME",
# ----> 2                                "DISBURSE_TIME", "RAISED_TIME"])
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1747                 raise ValueError("Usecols do not match names.")
#    1748
# -> 1749         self._set_noconvert_columns()
#    1750
#    1751         self.orig_names = self.names
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in _set_noconvert_columns(self)
#    1815                         _set(k)
#    1816                 else:
# -> 1817                     _set(val)
#    1818
#    1819         elif isinstance(self.parse_dates, dict):
#
# /anaconda2/envs/wordplay/lib/python3.6/site-packages/pandas/io/parsers.py in _set(x)
#    1805
#    1806             if not is_integer(x):
# -> 1807                 x = names.index(x)
#    1808
#    1809             self._reader.set_noconvert(x)
#
# ValueError: 'POSTED_TIME' is not in list

# %%
NEW_names = ["LOAN_ID","LOAN_NAME","ORIGINAL_LANGUAGE","DESCRIPTION","DESCRIPTION_TRANSLATED","FUNDED_AMOUNT","LOAN_AMOUNT","STATUS","IMAGE_ID","VIDEO_ID","ACTIVITY_NAME","SECTOR_NAME","LOAN_USE","COUNTRY_CODE","COUNTRY_NAME","TOWN_NAME","CURRENCY_POLICY","CURRENCY_EXCHANGE_COVERAGE_RATE","CURRENCY","PARTNER_ID","POSTED_TIME","PLANNED_EXPIRATION_TIME","DISBURSE_TIME","RAISED_TIME","LENDER_TERM","NUM_LENDERS_TOTAL","NUM_JOURNAL_ENTRIES","NUM_BULK_ENTRIES","TAGS","BORROWER_NAMES","BORROWER_GENDERS","BORROWER_PICTURED","REPAYMENT_INTERVAL","DISTRIBUTION_MODEL"]

# %%
OLD_names = ['id','name','original_language','original_description','translated_description','funded_amount','loan_amount','status','image_id','video_id','activity','sector','use','country_code','country_name','town','currency_policy', 'currency_exchange_coverage_rate','currency','partner_id','posted_time','planned_expiration_time','disbursed_time','funded_time','term_in_months','lender_count','journal_entries_count','bulk_journal_entries_count','tags','borrower_names','borrower_genders','borrower_pictured','repayment_interval','distribution_model']

# %%
dic = {}
for (k,v) in zip(NEW_names, OLD_names):
    dic[k]=v

# %%
df = df.rename(columns=dic)

# %%
df.head()
# Out:
#        id            name original_language  \
# 0  657307            Aivy           English
# 1  657259  Idalia Marizza           Spanish
# 2  658010           Aasia           English
# 3  659347         Gulmira           Russian
# 4  656933         Ricky\t           English
#
#                                 original_description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               translated_description  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status   image_id  video_id         ...          \
# 0        125.0  funded  1511246.0       NaN         ...
# 1        400.0  funded  1507947.0       NaN         ...
# 2        400.0  funded  1512245.0       NaN         ...
# 3        625.0  funded  1514419.0       NaN         ...
# 4        425.0  funded  1506830.0       NaN         ...
#
#   term_in_months lender_count journal_entries_count  \
# 0            7.0            3                     2
# 1            8.0           11                     2
# 2           14.0           16                     2
# 3           14.0           21                     2
# 4            7.0           15                     2
#
#   bulk_journal_entries_count  \
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
#
#                                                 tags  borrower_names  \
# 0                                                NaN            Aivy
# 1                                                NaN  Idalia Marizza
# 2  #Woman Owned Biz, #Supporting Family, user_fav...           Aasia
# 3                                      user_favorite         Gulmira
# 4           #Animals, #Eco-friendly, #Sustainable Ag         Ricky\t
#
#   borrower_genders  borrower_pictured repayment_interval  distribution_model
# 0           female               true          irregular       field_partner
# 1           female               true            monthly       field_partner
# 2           female               true            monthly       field_partner
# 3           female               true            monthly       field_partner
# 4             male               true             bullet       field_partner
#
# [5 rows x 34 columns]

# %%
df['year'] = df['posted_time'].dt.year #create year column

# %%
df.shape
# Out:
# (1419607, 35)

# %%
df = df[(df['status'] == 'funded') | (df['status'] == 'expired')]  #only take rows with 'funded' or 'expired' status

# %%
df.shape
# Out:
# (1409421, 35)

# %%
df.dropna(subset=['borrower_genders'], inplace=True)  # not interested in rows where gender is missing
df.reset_index(drop=True,inplace=True)

# %%
df.shape
# Out:
# (1372748, 35)

# %%
data = df[['borrower_genders', 'loan_amount', 'sector', 'country_name', 'status', 'year']]  # cols

# %%
def genders_groups(x):
    x = x.split(', ')
    if len(x) == 1:
        return x[0]
    else:
        genders = Counter(x).keys()
        if 'female' in genders and 'male' not in genders:
            return 'female_group'
        elif 'female' in genders and 'male' in genders:
            return 'mixed_group'
        else:
            return 'male_group'

# %%
data['gender_group'] = data['borrower_genders'].map(genders_groups)
# Out:
# /Users/ting2liu/anaconda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#   borrower_genders  loan_amount       sector country_name  status  year  \
# 0           female        125.0       Retail  Philippines  funded  2014
# 1           female        400.0     Clothing     Honduras  funded  2014
# 2           female        400.0       Retail     Pakistan  funded  2014
# 3           female        625.0  Agriculture   Kyrgyzstan  funded  2014
# 4             male        425.0  Agriculture  Philippines  funded  2014
#
#   gender_group
# 0       female
# 1       female
# 2       female
# 3       female
# 4         male

# %%
f = data.groupby(['year', 'gender_group', 'sector'])

# %%
final = f['loan_amount'].agg(['mean','size']).reset_index()
final
# Out:
#      year  gender_group          sector         mean  size
# 0    2006        female     Agriculture   521.607143   140
# 1    2006        female            Arts   776.428571    35
# 2    2006        female        Clothing   606.904762   210
# 3    2006        female    Construction   612.500000    32
# 4    2006        female            Food   574.211712   666
# 5    2006        female          Health   991.250000    20
# 6    2006        female         Housing   435.869565    23
# 7    2006        female   Manufacturing   748.333333    15
# 8    2006        female          Retail   612.331839   446
# 9    2006        female        Services   683.407080   226
# 10   2006        female  Transportation   554.166667     6
# 11   2006          male     Agriculture  1100.000000    72
# 12   2006          male            Arts   806.944444    18
# 13   2006          male        Clothing   648.837209    43
# 14   2006          male    Construction   871.428571    42
# 15   2006          male   Entertainment   635.000000     5
# 16   2006          male            Food   777.360515   233
# 17   2006          male          Health   622.727273    11
# 18   2006          male         Housing   428.846154    13
# 19   2006          male   Manufacturing   985.869565    23
# 20   2006          male          Retail   774.803150   127
# 21   2006          male        Services   857.083333   120
# 22   2006          male  Transportation   938.888889    27
# 23   2007        female     Agriculture   589.721455  2172
# 24   2007        female            Arts   542.399173   967
# 25   2007        female        Clothing   614.994678  1879
# 26   2007        female    Construction   687.197581   248
# 27   2007        female       Education   781.521739    23
# 28   2007        female   Entertainment   327.777778     9
# 29   2007        female            Food   548.189669  6021
# ..    ...           ...             ...          ...   ...
# 781  2017    male_group            Arts   525.000000     1
# 782  2017    male_group        Clothing  1250.000000    19
# 783  2017    male_group    Construction  1233.333333     9
# 784  2017    male_group       Education   680.000000     5
# 785  2017    male_group            Food  1478.611111    90
# 786  2017    male_group          Health  1454.166667     6
# 787  2017    male_group         Housing   990.000000     5
# 788  2017    male_group   Manufacturing  1159.375000     8
# 789  2017    male_group    Personal Use   209.737418   457
# 790  2017    male_group          Retail  1164.144737    76
# 791  2017    male_group        Services  1810.156250    32
# 792  2017    male_group  Transportation   843.421053    19
# 793  2017   mixed_group     Agriculture  1254.630571  5901
# 794  2017   mixed_group            Arts  3339.285714    91
# 795  2017   mixed_group        Clothing  3659.958217   718
# 796  2017   mixed_group    Construction  3252.616279    86
# 797  2017   mixed_group       Education  2178.947368    57
# 798  2017   mixed_group   Entertainment  2720.833333     6
# 799  2017   mixed_group            Food  3239.747697  2497
# 800  2017   mixed_group          Health  2173.469388    49
# 801  2017   mixed_group         Housing  1820.422535    71
# 802  2017   mixed_group   Manufacturing  2207.843137    51
# 803  2017   mixed_group    Personal Use   287.103714  4416
# 804  2017   mixed_group          Retail  3381.120827  1258
# 805  2017   mixed_group        Services  3022.720798   351
# 806  2017   mixed_group  Transportation  1963.366337   101
# 807  2017   mixed_group       Wholesale  1780.000000     5
# 808  2018        female     Agriculture    27.272727    11
# 809  2018  female_group     Agriculture    31.250000     4
# 810  2018          male        Clothing    50.000000     1
#
# [811 rows x 5 columns]

# %%
final_data = final.query('year != 2018 and year !=2006')

# %%
final_data.to_csv('loans_final.csv', index=False)
